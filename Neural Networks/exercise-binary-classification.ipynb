# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *
# Out:
# /tmp/ipykernel_25/3338970720.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu', input_shape=[33]),
    layers.BatchNormalization(),
    layers.Dropout(rate=0.3),
    layers.Dense(256, activation='relu'),    
    layers.BatchNormalization(),
    layers.Dropout(rate=0.3),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# 2025-01-15 18:59:13.413545: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-15 18:59:13.413710: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-15 18:59:13.556305: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1736967569.839542      66 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 175/175 [==============================] - 7s 7ms/step - loss: 0.4818 - binary_accuracy: 0.7730 - val_loss: 0.4373 - val_binary_accuracy: 0.7913
# Epoch 2/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.4231 - binary_accuracy: 0.8015 - val_loss: 0.4029 - val_binary_accuracy: 0.8128
# Epoch 3/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.4104 - binary_accuracy: 0.8088 - val_loss: 0.3960 - val_binary_accuracy: 0.8123
# Epoch 4/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.4027 - binary_accuracy: 0.8123 - val_loss: 0.3919 - val_binary_accuracy: 0.8194
# Epoch 5/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3973 - binary_accuracy: 0.8155 - val_loss: 0.3866 - val_binary_accuracy: 0.8201
# Epoch 6/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3927 - binary_accuracy: 0.8177 - val_loss: 0.3839 - val_binary_accuracy: 0.8216
# Epoch 7/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3876 - binary_accuracy: 0.8204 - val_loss: 0.3793 - val_binary_accuracy: 0.8242
# Epoch 8/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3846 - binary_accuracy: 0.8210 - val_loss: 0.3770 - val_binary_accuracy: 0.8232
# Epoch 9/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3814 - binary_accuracy: 0.8232 - val_loss: 0.3746 - val_binary_accuracy: 0.8262
# Epoch 10/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3781 - binary_accuracy: 0.8251 - val_loss: 0.3716 - val_binary_accuracy: 0.8276
# Epoch 11/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3763 - binary_accuracy: 0.8265 - val_loss: 0.3714 - val_binary_accuracy: 0.8284
# Epoch 12/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3753 - binary_accuracy: 0.8264 - val_loss: 0.3697 - val_binary_accuracy: 0.8274
# Epoch 13/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3710 - binary_accuracy: 0.8285 - val_loss: 0.3700 - val_binary_accuracy: 0.8313
# Epoch 14/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3689 - binary_accuracy: 0.8293 - val_loss: 0.3654 - val_binary_accuracy: 0.8308
# Epoch 15/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3670 - binary_accuracy: 0.8296 - val_loss: 0.3641 - val_binary_accuracy: 0.8322
# Epoch 16/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3650 - binary_accuracy: 0.8314 - val_loss: 0.3634 - val_binary_accuracy: 0.8320
# Epoch 17/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3637 - binary_accuracy: 0.8322 - val_loss: 0.3617 - val_binary_accuracy: 0.8332
# Epoch 18/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3606 - binary_accuracy: 0.8331 - val_loss: 0.3613 - val_binary_accuracy: 0.8332
# Epoch 19/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3598 - binary_accuracy: 0.8342 - val_loss: 0.3587 - val_binary_accuracy: 0.8338
# Epoch 20/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3590 - binary_accuracy: 0.8338 - val_loss: 0.3602 - val_binary_accuracy: 0.8344
# Epoch 21/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3567 - binary_accuracy: 0.8360 - val_loss: 0.3588 - val_binary_accuracy: 0.8347
# Epoch 22/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3563 - binary_accuracy: 0.8357 - val_loss: 0.3565 - val_binary_accuracy: 0.8359
# Epoch 23/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3555 - binary_accuracy: 0.8354 - val_loss: 0.3558 - val_binary_accuracy: 0.8356
# Epoch 24/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3531 - binary_accuracy: 0.8370 - val_loss: 0.3577 - val_binary_accuracy: 0.8349
# Epoch 25/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3533 - binary_accuracy: 0.8370 - val_loss: 0.3546 - val_binary_accuracy: 0.8371
# Epoch 26/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3511 - binary_accuracy: 0.8385 - val_loss: 0.3535 - val_binary_accuracy: 0.8355
# Epoch 27/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3511 - binary_accuracy: 0.8382 - val_loss: 0.3549 - val_binary_accuracy: 0.8349
# Epoch 28/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3492 - binary_accuracy: 0.8400 - val_loss: 0.3534 - val_binary_accuracy: 0.8372
# Epoch 29/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3487 - binary_accuracy: 0.8391 - val_loss: 0.3542 - val_binary_accuracy: 0.8369
# Epoch 30/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3459 - binary_accuracy: 0.8420 - val_loss: 0.3528 - val_binary_accuracy: 0.8376
# Epoch 31/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3478 - binary_accuracy: 0.8390 - val_loss: 0.3529 - val_binary_accuracy: 0.8368
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?
#
# --> Accuracy and cross-entropy seem to be inversely related, which is what we want. So cross-entropy losee is a good stand-in for accuracy. There is no overfitting but there might be a little bit of underfitting. But the accuracy gap is still very close so it isn't bad at all.

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
