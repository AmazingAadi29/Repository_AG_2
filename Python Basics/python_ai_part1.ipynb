# %% [markdown]
# <a href="https://colab.research.google.com/github/AmazingAadi29/Repository_AG/blob/main/python_ai_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this tutorial, we will cover Basic Python in this Google Colab environment.
#
#
#
# 1.   Basic data types (Containers, Lists, Dictionaries)
# 2.   Functions
# 3.   Classes

# %% [markdown]
# # A Brief Note on Python Versions
# As of Janurary 1, 2020, Python has officially dropped support for python2. We'll be using Python 3.7 for this iteration of the course. You can check your Python version at the command line by running `python --version`. In Colab, we can enforce the Python version by clicking `Runtime -> Change Runtime Type` and selecting `python3`. Note that as of April 2020, Colab uses Python 3.6.9 which should run everything without any errors.

# %%
# Check python version

# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# * Python is a high-level, *dynamically typed* multiparadigm programming language.
# * Python code is often said to be *almost like pseudocode*, since it allows you to express very powerful ideas in very few lines of code while being very readable.
#
# As an example, here is an implementation of the classic quicksort algorithm in Python:

# %% [markdown]
# **What do we mean by dynamically typed programming language?**
#
# It's a language that checks the data type of a variable at runtime - don't have to tell the program.

# %%
def quicksort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quicksort(left) + middle + quicksort(right)

print(quicksort([3,6,8,10,1,2,1]))
# Out:
# [1, 1, 2, 3, 6, 8, 10]

# %% [markdown]
# # Basic Data Types

# %% [markdown]
# ## Numbers

# %% [markdown]
# Integers and floats work as you would expect from other languages like Java:

# %%
# create a variable x, initialize it to 10
# print x and its data type

x = 10
print(x, type(x))
# Out:
# 10 <class 'int'>

# %%
# Addition - add 1 to x and print

print(x+1)

# Subtraction - subtract 1 from x and print

print(x-1)

# Multiplication - multiply x by 2 and print

print(x*2)

# Exponentiation - print the result of x to the power of 2

print(x**2)
# Out:
# 11
# 9
# 20
# 100

# %%
# Increment x by 2, save it to itself and print

x = x + 2
print(x)

# Decrement x by 2, save it to itself and print

x = x - 2
print(x)

# Multiply x by 2, save it to itself and print

x = 2*x
print(x)

# Divide x by 2, save it to itself and print

x = x/2
print(x)
# Out:
# 12.0
# 10.0
# 20.0
# 10.0

# %%
# Working with floats
y = 2.5

print(type(y))

print(y, y + 1, y * 2, y ** 2)
# Out:
# <class 'float'>
# 2.5 3.5 5.0 6.25

# %% [markdown]
# Note that unlike many languages, Python does not have unary increment (x++) or decrement (x--) operators.

# %% [markdown]
# ## Booleans

# %% [markdown]
# Python implements all of the usual operators for Boolean logic, but uses English words rather than symbols (&&, ||, etc.):

# %%
t, f = True, False

print(type(f))
print(type(t))
# ADD CODE HERE
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
print(t and f)

print(t or f)

print(not t)

print(t != f)
# Out:
# False
# True
# False
# True

# %% [markdown]
# ## Strings

# %%
from typing import Sized
hello = 'hello'   # String literals can use single quotes
world = "world"   # or double quotes; it does not matter

# print hello and its length

print(hello, len(hello))
# Out:
# hello 5

# %%
hw12 = '{} {} {}'.format(hello, world, 12)  # string formatting
print(hw12)
# Out:
# hello world 12

# %% [markdown]
# String objects have a bunch of useful methods; for example:

# %%
s = "     hello"
# Capitalize a string

print(s.capitalize())

# Convert a string to uppercase; prints "HELLO"

print(s.upper())

# Right-justify a string, padding with spaces

print(s.rjust(50))

# Center a string, padding with spaces

print(s.center(50))

# Replace all instances of one substring with another

print(s.replace('hello','chicken',1))

# Strip leading and trailing whitespace

print(s.strip())
# Out:
#      hello
#      HELLO
#                                              hello
#                          hello
#      chicken
# hello

# %% [markdown]
# # Containers

# %% [markdown]
# ## Lists

# %% [markdown]
# A list is the Python equivalent of an array, but is resizeable and can contain elements of different types:

# %%
xs = [3, 1, 2]   # Create a list

print(xs)

# print the length of the list

print(len(xs))

# print the second element in the list

print(xs[1])

# Negative indices count from the end of the list; print the element "2"

print(xs[-1])

# Lists can contain elements of different types

xs[2] = 'Abyaan Khwaja'
print(xs)
# Out:
# [3, 1, 2]
# 3
# 1
# 2
# [3, 1, 'Abyaan Khwaja']

# %%
# Lists can contain elements of different types

# Set element at index 2 of the list to a string 'foo'



print(xs)
# Out:
# [3, 1, 'Abyaan Khwaja', 'bar']

# %%
# Add a new element - string 'bar' - to the end of the list

xs.append('bar')

print(xs)
# Out:
# [3, 1, 'Abyaan Khwaja', 'bar', 'bar']

# %%
# Remove and return the last element of the list

x = xs.pop()
print(x, xs)
# Out:
# bar [3, 1, 'Abyaan Khwaja', 'bar']

# %% [markdown]
# ## Slicing

# %% [markdown]
# In addition to accessing list elements one at a time, Python provides concise syntax to access sublists; this is known as slicing:

# %%
# range is a built-in function that creates a list of integers
nums = list(range(5))
print(nums)
# Out:
# [0, 1, 2, 3, 4]

# %%
# Get a slice from index 2 to 4 (exclusive); prints "[nums[2:4]

nums[2:4]
# Out:
# [2, 3]

# %%
# Get a slice from index 2 to the end; prints "[2, 3, 4]"

nums[2:]
# Out:
# [2, 3, 4]

# %%
# Get a slice from the start to index 2 (exclusive); prints "[0, 1]"

nums[:2]
# Out:
# [0, 1]

# %%
# Get a slice of the whole list; prints ["0, 1, 2, 3, 4]"

nums[0:]
# Out:
# [0, 1, 2, 3, 4]

# %%
# Slice indices can be negative; prints ["0, 1, 2, 3]"

nums[:-1]
# Out:
# [0, 1, 2, 3]

# %%
nums[2:4] = [8, 9] # Assign a new sublist to a slice
print(nums)         # Prints "[0, 1, 8, 9, 4]"
# Out:
# [0, 1, 8, 9, 4]

# %% [markdown]
# ## Loops

# %% [markdown]
# You can loop over the elements of a list like this:

# %%
animals = ['cat', 'dog', 'monkey']
for animal in animals:
    print(animal)
# Out:
# cat
# dog
# monkey

# %% [markdown]
# If you want access to the index of each element within the body of a loop, use the built-in `enumerate` function:

# %%
animals = ['cat', 'dog', 'monkey']
for idx, animal in enumerate(animals):
    print(idx+1, animal)
# Out:
# 1 cat
# 2 dog
# 3 monkey

# %% [markdown]
# ## List comprehensions

# %% [markdown]
# When programming, frequently we want to transform one type of data into another. As a simple example, consider the following code that computes square numbers:

# %%
nums = [0, 1, 2, 3, 4]
squares = []
for x in nums:
    squares.append(x ** 2)
print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %% [markdown]
# You can make this code simpler using a list comprehension:

# %%
nums = [0, 1, 2, 3, 4]

squares = [x**2 for x in nums]

print(squares)
# Out:
# [0, 1, 4, 9, 16]

# %% [markdown]
# List comprehensions can also contain conditions:

# %%
nums = [0, 1, 2, 3, 4]
even_squares = [x**2 for x in nums if x % 2 == 0]
print(even_squares)
# Out:
# [0, 4, 16]

# %% [markdown]
# ## Dictionary

# %% [markdown]
# A dictionary stores (key, value) pairs, similar to a `Map` in Java or an object in Javascript. You can use it like this:

# %%
d = {'cat': 'cute', 'dog': 'furry'}  # Create a new dictionary with some data

print(d['cat'])

# Check if a dictionary has a given key; prints "True"

if(d['cat']) == 'cute':
  x = True;
  print(x)
# Out:
# cute
# True

# %%
d['fish'] = 'wet'    # Set an entry in a dictionary
print(d['fish'])      # Prints "wet"

# %%
print(d['monkey'])  # KeyError: 'monkey' not a key of d

# %%
print(d.get('monkey', 'N/A'))  # Get an element with a default; prints "N/A"
print(d.get('fish', 'N/A'))    # Get an element with a default; prints "wet"

# %%
del d['fish']        # Remove an element from a dictionary
print(d.get('fish', 'N/A')) # "fish" is no longer a key; prints "N/A"

# %% [markdown]
# It is easy to iterate over the keys in a dictionary:

# %%
d = {'person': 2, 'cat': 4, 'spider': 8}
for animal, legs in d.items():
    print('A {} has {} legs'.format(animal, legs))

# %% [markdown]
# Dictionary comprehensions: These are similar to list comprehensions, but allow you to easily construct dictionaries. For example:

# %%
nums = [0, 1, 2, 3, 4]
even_num_to_square = {x: x ** 2 for x in nums if x % 2 == 0}
print(even_num_to_square)
# Out:
# {0: 0, 2: 4, 4: 16}

# %%
# Print odd numbers squares using dictionary comprehensions

nums = [0, 1, 2, 3, 4]
odd_num_to_square = {x: x ** 2 for x in nums if x % 2 == 1}
print(odd_num_to_square)
# Out:
# {1: 1, 3: 9}

# %% [markdown]
# # Functions
#
# Python functions are defined using the `def` keyword. For example:

# %%
nums = [-1, 0, 1]

def sign(x):
  if x > 0:
    print('POSITIVE')
  else:
    if x < 0:
      print('NEGATIVE')
    else:
      if x == 0:
        print('ZEROOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO')

for x in nums:
    print(x, sign(x))
# Out:
# NEGATIVE
# -1 None
# ZEROOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# 0 None
# POSITIVE
# 1 None

# %% [markdown]
# We will often define functions to take optional keyword arguments, like this:

# %%
def hello(name, loud=False):
    if loud:
        print('HELLO, {}'.format(name.upper()))
    else:
        print('Hello, {}!'.format(name))

hello('Bob')
hello('Fred', loud=True)
# Out:
# Hello, Bob!
# HELLO, FRED

# %% [markdown]
# `main()` function
#
# `def main():`
#
# This defines the `main` function where the primary logic of your program will reside. You can include any code or function calls here.
#
# `if __name__ == "__main__":`
#
# This conditional statement checks if the script is being run directly (not imported as a module).
# `__name__` is a special variable that Python sets to `"__main__"` when the script is run directly. If the script is imported into another script, `__name__` will be set to the script's filename instead.
# If the script is being run directly, the `main()` function is called.

# %%
def main():

    print("This is the main function.")

    # Main code goes here
    hello('Bob')
    hello('Fred', loud=True)

if __name__ == "__main__":
    main()
# Out:
# This is the main function.
# Hello, Bob!
# HELLO, FRED

# %% [markdown]
# # Classes
#
# The syntax for defining classes in Python is straightforward:

# %%
class Greeter:

    # Constructor
    def __init__(self, name):
        self.name = name  # Create an instance variable

    # Instance method
    def greet(self, loud=False):
        if loud:
          print('HELLO, {}'.format(self.name.upper()))
        else:
          print('Hello, {}!'.format(self.name))

g = Greeter('Fred')  # Construct an instance of the Greeter class
g.greet()            # Call an instance method; prints "Hello, Fred"
g.greet(loud=True)   # Call an instance method; prints "HELLO, FRED!"
# Out:
# Hello, Fred!
# HELLO, FRED

# %% [markdown]
# # Student Tracker Assignment:
#
# Create a simple program that allows a user to track and display student grades. This assignment focuses on the use of lists, dictionaries, and basic class structure.

# %% [markdown]
# Define a Student Class:
#
# The class should have the following attributes:
#
#
# *   `name` (string): The student's name.
# *   `grades` (dictionary): A dictionary where the keys are subjects and the values are grades.
#
# The class should have methods to:
# * Add or update a grade for a subject.
# * Display the student's information, including their grades.

# %%
class Student:

  # Constructor - defining the name
  def __init__(self, name):
    self.name = name  # Instance Variable - initializing student's name
    self.grades = {} # Initializing dictionary to store subjects (keys) and grades (values)

  def add_grade(self, subject, grades):
    self.grades[subject] = grades # Subject --> Grades: calls subject, sets the value of the key as the added grade
    print(f"{self.name}'s grade in {subject} is {grades}")

  def student_info(self): # Display student subject and grade
    print(self.name)
    print(self.grades)

# %% [markdown]
# Create a Function to Manage Students:
#
# This function will:
# 1. Create a list of Student objects.
# 2. Add grades for each student.
# 3. Display all students' information.

# %%
def manage_students():
  # ADD CODE HERE
  students = [] # Creating list of students

  # Adding Abyaan, Sid and Youfus to my list of students
  Abyaan = Student("Abyaan")
  Sid = Student("Sid")
  Youfus = Student("Youfus")

  students.append(Abyaan)
  students.append(Sid)
  students.append(Youfus)

  # Giving them grades
  Abyaan.add_grade("Dance", 98)
  Abyaan.add_grade("Theatre", 96)
  Sid.add_grade("IB Chem HL", 99)
  Sid.add_grade("IB AA HL", 95)
  Youfus.add_grade("Environmental Science", 63)
  Youfus.add_grade("English IV", 72)

  #call method "student_info" for each student in students
  for student in students:
    student.student_info()

# %% [markdown]
# Implement the Main Program:
#
# Call the `manage_students` function to run the program.

# %%
if __name__ == "__main__":
    manage_students()
# Out:
# Abyaan's grade in Dance is 98
# Abyaan's grade in Theatre is 96
# Sid's grade in IB Chem HL is 99
# Sid's grade in IB AA HL is 95
# Youfus's grade in Environmental Science is 63
# Youfus's grade in English IV is 72
# Abyaan
# {'Dance': 98, 'Theatre': 96}
# Sid
# {'IB Chem HL': 99, 'IB AA HL': 95}
# Youfus
# {'Environmental Science': 63, 'English IV': 72}
